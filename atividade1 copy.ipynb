# %% [markdown]
# # Os 10 jogos mais vendidos do mundo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Criacao do dict com os jogos

# %%
dictGames = {
    'Raiden Shogun': 33,
    'Venti': 30.6,
    'Hu tao': 25.2,
    'Klee': 22.8,
    'Ayaka': 16.5
}

# %% [markdown]
# ### Criacao da series

# %%
seriesGames = pd.Series(dictGames)

# %% [markdown]
# ### Grafico com os valores da series

# %%
seriesGames.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Conclusao
#
# Com esse grafico podemos concluir que o banner da Raiden Shogun foi o mais vendido do ano de 2022 no jogo Genshin Impact.
