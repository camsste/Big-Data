# %% [markdown]
# # Os 10 jogos mais vendidos do mundo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Criacao do dict com os jogos

# %%
dictGames = {
    'Super Mario World': 48,
    'Overwatch': 50,
    'The Witcher 3': 50,
    'Red Dead Redemption 2': 55,
    'Mario Kart8 Deluxe': 62,
    'PUBG': 55,
    'Wii Sports': 82.9,
    'GTA San Andreas': 175,
    'Minecraft': 238,
    'Tetris': 520
}

# %% [markdown]
# ### Criacao da series

# %%
seriesGames = pd.Series(dictGames)

# %% [markdown]
# ### Grafico com os valores da series

# %%
seriesGames.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Conclusao
#
# Com esse grafico podemos concluir que Tetris é o jogos mais vendido do mundo.
